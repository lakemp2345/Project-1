# %%
import os
import glob
import pandas as pd
import scipy.stats as st
import numpy as np

# %%
# Study data files
path_1 = "Data/billboard_hot100_2016.csv"
path_2 = "Data/billboard_hot100_2017.csv"
path_3 = "Data/billboard_hot100_2018.csv"
path_4 = "Data/billboard_hot100_2019.csv"
path_5 = "Data/billboard_hot100_2020.csv"
path_6 = "Data/billboard_hot100_2021.csv"

billboard_hot100_2016 = pd.read_csv(path_1)
billboard_hot100_2017 = pd.read_csv(path_2)
billboard_hot100_2018 = pd.read_csv(path_3)
billboard_hot100_2019 = pd.read_csv(path_4)
billboard_hot100_2020 = pd.read_csv(path_5)
billboard_hot100_2021 = pd.read_csv(path_6)

combined = [billboard_hot100_2016, billboard_hot100_2017,billboard_hot100_2018, billboard_hot100_2019, billboard_hot100_2020, billboard_hot100_2021]

# Combine the data into a single dataset
# Display the data table for preview
Combine_df = pd.concat(combined, ignore_index = True)
Combine_df
# Out:
#              Date                              Title  \
# 0      2016-01-02                              Hello
# 1      2016-01-02                              Sorry
# 2      2016-01-02                      Hotline Bling
# 3      2016-01-02                      Love Yourself
# 4      2016-01-02                  What Do You Mean?
# ...           ...                                ...
# 28595  2021-06-19           Things A Man Oughta Know
# 28596  2021-06-19                      Country Again
# 28597  2021-06-19  Drunk (And I Don't Wanna Go Home)
# 28598  2021-06-19                     If You Want To
# 28599  2021-06-19                       Seeing Green
#
#                                Artist  Rank  Is_New  Image  Peak_Posistion  \
# 0                               Adele     1   False    NaN               1
# 1                       Justin Bieber     2   False    NaN               2
# 2                               Drake     3   False    NaN               2
# ...

# %%
Combine_df.to_csv("Data/billboard_hot100_16-21.csv", index=False)
